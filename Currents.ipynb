# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Analysis of ion currents

# %% [markdown]
# Read all files with current

# %%
data = {}
files = []
for filename in os.listdir('.'):
    if filename.startswith('curr'):
        values = pd.read_csv(filename, sep = ' ', names=['t', 'I'])
        values = values[(values['t'] > 50) & (values['t'] < 190)]
        values['I_cum'] = np.cumsum([values['I']])
        data[filename[:-6]] = values
        files.append(filename[:-6])
        
        name = filename[:-4].split('_')
        current_type = name[0]
        mutant = name[1]
        voltage = int(name[2][:-2])
        print(filename[:-6])
        display(data[filename[:-6]].head(3))
        print(len(values))
# Out:
# currPOT_R220Q_150
#          t         I     I_cum
# 499  50.05  0.219885  0.219885
# 500  50.15  0.083976  0.303861
# 501  50.25  0.171267  0.475128
# 1400
# currCLA_R220A_150
#          t         I     I_cum
# 499  50.05  1.599967  1.599967
# 500  50.15  0.517117  2.117084
# 501  50.25 -2.773424 -0.656340
# 1400
# currPOT_Wt_250
#          t         I     I_cum
# 499  50.05  1.076221  1.076221
# 500  50.15 -0.449715  0.626507
# 501  50.25 -0.409937  0.216570
# 1400
# currPOT_Wt_-150
#          t         I     I_cum
# 499  50.05  0.828713  0.828713
# 500  50.15 -0.480653  0.348059
# 501  50.25 -0.677334 -0.329275
# 1400
# curr_R220W_150
#          t         I     I_cum
# 499  50.05 -0.617667 -0.617667
# 500  50.15  0.402202 -0.215465
# 501  50.25  1.280637  1.065172
# 1400
# currPOT_K238N_150
#          t         I     I_cum
# 499  50.05  3.422030  3.422030
# 500  50.15  0.141433  3.563463
# 501  50.25 -1.148043  2.415420
# 1400
# currCLA_Wt_150
#          t         I     I_cum
# 499  50.05  2.312660  2.312660
# 500  50.15 -1.233124  1.079536
# 501  50.25 -0.097235  0.982300
# 1400
# currCLA_K238A_-150
#          t         I     I_cum
# 499  50.05 -1.712672 -1.712672
# 500  50.15  0.458554 -1.254118
# 501  50.25  2.618731  1.364613
# 1400
# curr_Wt_0
#          t         I     I_cum
# 499  50.05  2.032003  2.032003
# 500  50.15 -0.394467  1.637536
# 501  50.25  1.113789  2.751325
# 1400
# curr_R282W_150
#          t         I     I_cum
# 499  50.05 -0.830923 -0.830923
# 500  50.15  1.892779  1.061857
# 501  50.25 -1.352459 -0.290602
# 1400
# currCLA_K238R_150
#          t         I     I_cum
# 499  50.05 -0.292812 -0.292812
# 500  50.15 -0.046408 -0.339220
# 501  50.25 -3.609872 -3.949091
# 1400
# curr_Wt_150
#          t         I     I_cum
# 499  50.05  1.976755  1.976755
# 500  50.15 -3.469543 -1.492787
# 501  50.25  2.047472  0.554685
# 1400
# currPOT_K238A_-150
#          t         I     I_cum
# 499  50.05  2.906019  2.906019
# 500  50.15 -1.034233  1.871785
# 501  50.25  1.458534  3.330319
# 1400
# currPOT_K238W_150
#          t         I     I_cum
# 499  50.05 -0.080661 -0.080661
# 500  50.15  0.340325  0.259663
# 501  50.25 -0.130384  0.129279
# 1400
# currCLA_Wt_250
#          t         I     I_cum
# 499  50.05  0.691699  0.691699
# 500  50.15  0.219885  0.911584
# 501  50.25  0.298337  1.209920
# 1400
# currCLA_K238N_150
#          t         I     I_cum
# 499  50.05  0.731477  0.731477
# 500  50.15 -0.565734  0.165743
# 501  50.25  0.964621  1.130364
# 1400
# currCLA_R282W_150
#          t         I     I_cum
# 499  50.05  2.620941  2.620941
# 500  50.15  1.380083  4.001024
# 501  50.25 -2.135868  1.865155
# 1400
# curr_Wt_250
#          t        I    I_cum
# 499  50.05  1.76792  1.76792
# 500  50.15 -0.22983  1.53809
# 501  50.25 -0.11160  1.42649
# 1400
# curr_K238N_150
#          t         I     I_cum
# 499  50.05  4.153507  4.153507
# 500  50.15 -0.424301  3.729206
# 501  50.25 -0.183421  3.545784
# 1400
# currPOT_R220W_150
#          t         I     I_cum
# 499  50.05 -0.925948 -0.925948
# 500  50.15  0.179002 -0.746946
# 501  50.25  0.061877 -0.685069
# 1400
# currPOT_K242W_150
#          t         I     I_cum
# 499  50.05 -3.678378 -3.678378
# 500  50.15  1.164617 -2.513761
# 501  50.25 -1.569029 -4.082790
# 1400
# currCLA_Wt_0
#          t         I     I_cum
# 499  50.05  0.944732  0.944732
# 500  50.15 -0.127069  0.817663
# 501  50.25  1.552454  2.370118
# 1400
# currCLA_K238W_150
#          t         I     I_cum
# 499  50.05 -0.612142 -0.612142
# 500  50.15  0.787829  0.175687
# 501  50.25 -0.151378  0.024309
# 1400
# curr_R282A_150
#          t         I     I_cum
# 499  50.05  0.951362  0.951362
# 500  50.15  0.816558  1.767920
# 501  50.25  0.606618  2.374537
# 1400
# curr_K238A_-150
#          t         I     I_cum
# 499  50.05  1.193346  1.193346
# 500  50.15 -0.575679  0.617667
# 501  50.25  4.077265  4.694932
# 1400
# curr_R220E_150
#          t         I     I_cum
# 499  50.05  0.524851  0.524851
# 500  50.15 -1.728142 -1.203291
# 501  50.25  2.318185  1.114895
# 1400
# curr_K238R_150
#          t         I     I_cum
# 499  50.05 -0.815453 -0.815453
# 500  50.15 -0.504962 -1.320415
# 501  50.25 -4.143562 -5.463978
# 1400
# curr_R220A_150
#          t         I     I_cum
# 499  50.05  1.306051  1.306051
# 500  50.15 -0.302756  1.003294
# 501  50.25 -1.039758 -0.036463
# 1400
# currCLA_R220Q_150
#          t         I     I_cum
# 499  50.05 -0.180107 -0.180107
# 500  50.15 -1.304946 -1.485053
# 501  50.25  0.185631 -1.299421
# 1400
# currCLA_K242W_150
#          t         I     I_cum
# 499  50.05  1.178981  1.178981
# 500  50.15  1.645270  2.824252
# 501  50.25 -0.095026  2.729226
# 1400
# currPOT_R220K_150
#          t         I     I_cum
# 499  50.05  0.521536  0.521536
# 500  50.15  1.578974  2.100510
# 501  50.25  2.868450  4.968960
# 1400
# currPOT_R282A_150
#          t         I     I_cum
# 499  50.05  0.364633  0.364633
# 500  50.15  0.385628  0.750261
# 501  50.25  0.533691  1.283952
# 1400
# curr_R220K_150
#          t         I     I_cum
# 499  50.05  0.940312  0.940312
# 500  50.15  1.506047  2.446359
# 501  50.25  2.406581  4.852940
# 1400
# currCLA_Wt_-150
#          t         I     I_cum
# 499  50.05  1.522621  1.522621
# 500  50.15 -0.582308  0.940312
# 501  50.25 -0.838657  0.101655
# 1400
# curr_Wt_-150
#          t         I     I_cum
# 499  50.05  2.351333  2.351333
# 500  50.15 -1.062962  1.288372
# 501  50.25 -1.515991 -0.227620
# 1400
# currPOT_R220E_150
#          t         I     I_cum
# 499  50.05 -0.997770 -0.997770
# 500  50.15  1.090586  0.092816
# 501  50.25  1.065172  1.157988
# 1400
# curr_K242W_150
#          t         I     I_cum
# 499  50.05 -2.499397 -2.499397
# 500  50.15  2.809888  0.310491
# 501  50.25 -1.664055 -1.353564
# 1400
# curr_K238W_150
#          t         I     I_cum
# 499  50.05 -0.692804 -0.692804
# 500  50.15  1.128154  0.435350
# 501  50.25 -0.281762  0.153588
# 1400
# currCLA_R282A_150
#          t         I     I_cum
# 499  50.05  0.586728  0.586728
# 500  50.15  0.430930  1.017659
# 501  50.25  0.072927  1.090586
# 1400
# currPOT_Wt_0
#          t         I     I_cum
# 499  50.05  1.087271  1.087271
# 500  50.15 -0.267398  0.819873
# 501  50.25 -0.438665  0.381208
# 1400
# currPOT_K242A_150
#          t         I     I_cum
# 499  50.05 -0.643081 -0.643081
# 500  50.15  1.644165  1.001085
# 501  50.25 -0.759101  0.241984
# 1400
# currPOT_K238Q_150
#          t         I     I_cum
# 499  50.05  2.209900  2.209900
# 500  50.15 -1.528145  0.681754
# 501  50.25 -0.735897 -0.054142
# 1400
# currCLA_R220E_150
#          t         I     I_cum
# 499  50.05  1.522621  1.522621
# 500  50.15 -2.818727 -1.296106
# 501  50.25  1.253013 -0.043093
# 1400
# curr_K238Q_150
#          t         I     I_cum
# 499  50.05  2.322605  2.322605
# 500  50.15 -0.001105  2.321500
# 501  50.25 -2.971210 -0.649710
# 1400
# currPOT_K238R_150
#          t         I     I_cum
# 499  50.05 -0.522641 -0.522641
# 500  50.15 -0.458554 -0.981196
# 501  50.25 -0.533691 -1.514886
# 1400
# currCLA_K242A_150
#          t         I     I_cum
# 499  50.05 -0.861861 -0.861861
# 500  50.15 -0.699433 -1.561294
# 501  50.25 -2.301611 -3.862905
# 1400
# currPOT_Wt_450
#          t         I     I_cum
# 499  50.05  0.966831  0.966831
# 500  50.15 -4.034172 -3.067341
# 501  50.25 -1.152463 -4.219804
# 1400
# curr_K242A_150
#          t         I     I_cum
# 499  50.05 -1.504942 -1.504942
# 500  50.15  0.944732 -0.560210
# 501  50.25 -3.060712 -3.620921
# 1400
# currPOT_R220A_150
#          t         I     I_cum
# 499  50.05 -0.293917 -0.293917
# 500  50.15 -0.819873 -1.113790
# 501  50.25  1.733666  0.619877
# 1400
# currPOT_Wt_150
#          t         I     I_cum
# 499  50.05 -0.335905 -0.335905
# 500  50.15 -2.236419 -2.572323
# 501  50.25  2.144708 -0.427616
# 1400
# curr_Wt_450
#          t         I     I_cum
# 499  50.05 -3.161262 -3.161262
# 500  50.15 -3.828651 -6.989913
# 501  50.25 -0.707168 -7.697081
# 1400
# currCLA_R220W_150
#          t         I     I_cum
# 499  50.05  0.308281  0.308281
# 500  50.15  0.223200  0.531481
# 501  50.25  1.218760  1.750241
# 1400
# currCLA_R220K_150
#          t         I     I_cum
# 499  50.05  0.418776  0.418776
# 500  50.15 -0.072927  0.345849
# 501  50.25 -0.461869 -0.116020
# 1400
# currCLA_Wt_450
#          t         I     I_cum
# 499  50.05 -4.128093 -4.128093
# 500  50.15  0.205521 -3.922572
# 501  50.25  0.445295 -3.477277
# 1400
# currPOT_R282W_150
#          t         I     I_cum
# 499  50.05 -3.451864 -3.451864
# 500  50.15  0.512697 -2.939167
# 501  50.25  0.783409 -2.155757
# 1400
# currCLA_K238Q_150
#          t         I     I_cum
# 499  50.05  0.112705  0.112705
# 500  50.15  1.527041  1.639746
# 501  50.25 -2.235314 -0.595568
# 1400
# curr_R220Q_150
#          t         I     I_cum
# 499  50.05  0.039778  0.039778
# 500  50.15 -1.220970 -1.181191
# 501  50.25  0.356899 -0.824293
# 1400

# %%
print(files)
# Out:
# ['currPOT_R220Q_150', 'currCLA_R220A_150', 'currPOT_Wt_250', 'currPOT_Wt_-150', 'curr_R220W_150', 'currPOT_K238N_150', 'currCLA_Wt_150', 'currCLA_K238A_-150', 'curr_Wt_0', 'curr_R282W_150', 'currCLA_K238R_150', 'curr_Wt_150', 'currPOT_K238A_-150', 'currPOT_K238W_150', 'currCLA_Wt_250', 'currCLA_K238N_150', 'currCLA_R282W_150', 'curr_Wt_250', 'curr_K238N_150', 'currPOT_R220W_150', 'currPOT_K242W_150', 'currCLA_Wt_0', 'currCLA_K238W_150', 'curr_R282A_150', 'curr_K238A_-150', 'curr_R220E_150', 'curr_K238R_150', 'curr_R220A_150', 'currCLA_R220Q_150', 'currCLA_K242W_150', 'currPOT_R220K_150', 'currPOT_R282A_150', 'curr_R220K_150', 'currCLA_Wt_-150', 'curr_Wt_-150', 'currPOT_R220E_150', 'curr_K242W_150', 'curr_K238W_150', 'currCLA_R282A_150', 'currPOT_Wt_0', 'currPOT_K242A_150', 'currPOT_K238Q_150', 'currCLA_R220E_150', 'curr_K238Q_150', 'currPOT_K238R_150', 'currCLA_K242A_150', 'currPOT_Wt_450', 'curr_K242A_150', 'currPOT_R220A_150', 'currPOT_Wt_150', 'curr_Wt_450', 'currCLA_R220W_150', 'currCLA_R220K_150', 'currCLA_Wt_450', 'currPOT_R282W_150', 'currCLA_K238Q_150', 'curr_R220Q_150']

# %% [markdown]
# Get average current by making linear fit of cumulutive sum

# %%
# Names of files
mutants = [s.split('_')[1] + '_' + s.split('_')[2] for s in files]

# Table with currents
summary = pd.DataFrame(columns=['mut', 'V', 'curr', 'curr_err',
                                'currCLA', 'currCLA_err', 'currPOT', 'currPOT_err'],
                       index = mutants)
for f in files:
    plt.plot(data[f]['t'], np.cumsum(data[f]['I']))
    p, cov = np.polyfit(data[f]['t'], np.cumsum(data[f]['I']), 1,cov = True)
    errorbars = np.sqrt(np.diag(cov))
    plt.plot(data[f]['t'], [p[0] * t + p[1] for t in data[f]['t']])
    plt.xlabel('Time, ns')
    plt.ylabel('Cumulative current')
    
    name = f.split('_')
    curr_type = name[0]
    mutant = name[1]
    voltage = name[2]
    summary.loc[mutant + '_' + voltage, 'mut'] = mutant
    summary.loc[mutant + '_' + voltage, 'V'] = int(voltage)
    summary.loc[mutant + '_' + voltage, curr_type] = p[0]
    summary.loc[mutant + '_' + voltage, curr_type + '_err'] = errorbars[0]

# %%
plt.plot(data['currPOT_K238R_150']['t'], np.cumsum(data['currPOT_K238R_150']['I']))

# %%
summary = summary.drop_duplicates()
summary['selectivity'] = (np.abs(summary['currCLA']) / np.abs(summary['currPOT']))
summary = summary.sort_index()
summary
# Out:
#               mut     V       curr    curr_err    currCLA currCLA_err  \
# K238A_-150  K238A  -150  -0.280363   0.0041271 -0.0259399  0.00182827
# K238N_150   K238N   150   0.690084  0.00290335   0.701303  0.00268192
# K238Q_150   K238Q   150   0.597027  0.00327289   0.474843  0.00241523
# K238R_150   K238R   150   0.488005  0.00469058   0.554504  0.00295012
# K238W_150   K238W   150   0.905182  0.00186503   0.778482  0.00129705
# K242A_150   K242A   150    1.00536  0.00358267   0.845434  0.00364519
# K242W_150   K242W   150   0.484404  0.00495451   0.460988  0.00258735
# R220A_150   R220A   150   0.557506  0.00295079   0.504518  0.00271496
# R220E_150   R220E   150   0.480303  0.00295508   0.395997  0.00211508
# R220K_150   R220K   150   0.607448  0.00461901   0.565226  0.00353722
# R220Q_150   R220Q   150   0.670662  0.00216223    0.60989   0.0012737
# R220W_150   R220W   150   0.424135   0.0016643   0.406911   0.0016882
# R282A_150   R282A   150   0.679714  0.00226357   0.659322  0.00246614
# R282W_150   R282W   150   0.761238  0.00406759   0.700402  0.00316698
# Wt_-150        Wt  -150  -0.497938  0.00243798  -0.132525  0.00132305
# Wt_0           Wt     0  0.0553134  0.00224669  0.0946258  0.00154668
# Wt_150         Wt   150   0.774929  0.00388248   0.685203  0.00295244
# Wt_250         Wt   250    1.08465  0.00465284    1.01388  0.00378332
# Wt_450         Wt   450     1.8804  0.00404918    1.73136  0.00400003
#
#               currPOT  currPOT_err selectivity
# K238A_-150  -0.254423   0.00343373    0.101956
# K238N_150  -0.0112192   0.00230589     62.5093
# K238Q_150    0.122184   0.00236191     3.88631
# K238R_150  -0.0664986   0.00274712     8.33858
# K238W_150    0.126701   0.00115757     6.14426
# K242A_150    0.159924   0.00231824     5.28649
# K242W_150    0.023416   0.00332991     19.6869
# R220A_150   0.0529877   0.00171439     9.52142
# R220E_150   0.0843056    0.0023904     4.69716
# R220K_150   0.0422224   0.00207278     13.3869
# R220Q_150   0.0607725   0.00115819     10.0356
# R220W_150    0.017224  0.000812902     23.6247
# R282A_150    0.020392  0.000842154     32.3325
# R282W_150   0.0608365    0.0022168     11.5129
# Wt_-150     -0.365413   0.00199709    0.362672
# Wt_0       -0.0393123   0.00170118     2.40703
# Wt_150      0.0897264   0.00198187     7.63658
# Wt_250      0.0707771   0.00185572     14.3249
# Wt_450       0.149037   0.00196091      11.617

# %% [markdown]
# There are some cases with very small negative current, probably we should set them to zero.
#
# In general we see that the chloride current is larger than potassium.

# %%
summary = summary[summary['V'] >= 0]
plt.figure(figsize=(7, 5))
plt.scatter(summary.index, summary.curr, label="Total current")
plt.scatter(summary.index, summary.currCLA, label='Chloride current')
plt.scatter(summary.index, summary.currPOT, label='Potassium current')
plt.xticks(rotation='vertical')
plt.ylabel('Current')
plt.legend()
